# %%
import time
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt



# %matplotlib inline
pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 200)
pd.options.display.float_format = '{:20,.1f}'.format

# %%
ruta = "./../data/"

# %%
file1 = "valores2.csv"

# %%
valores = pd.read_csv(ruta + file1)

# %%
valores.sample()
# Out:
#          p1     p2 group
# 1788  35579  39250     A

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="group",
    data=valores,
    legend="full",
    
    
)

# %%
result20 = pd.read_csv(ruta + "resvalores.csv")

# %%
valores["res20"] = result20

# %%
valores.sample()
# Out:
#          p1     p2 group  res20
# 2563  10919  50525     A      5

# %%
cmap = sns.cubehelix_palette(dark=.0, light=.9, as_cmap=True)
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="res20",
     #palette=cmap,
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['res20_super'].unique()))
    
)

# %%
result20_2 = pd.read_csv(ruta + "resvalores2.csv")
valores["res20_2"] = result20_2

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="res20_2",
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['res20_super'].unique()))
)

# %%
valores["res20_2"] .value_counts()
# Out:
# 9     311
# 0     282
# 14    276
# 1     167
# 18    155
# 16    153
# 13    152
# 11    151
# 17    150
# 10    150
# 5     149
# 15    149
# 4     149
# 8     147
# 7     146
# 12    108
# 2      64
# 6      52
# 3      48
# 19     41
# Name: res20_2, dtype: int64

# %% [markdown]
# otro

# %%
result20_super = pd.read_csv(ruta + "resvaloressuperkmeans.csv")
valores["res20_super"] = result20_super

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="res20_super",
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['res20_super'].unique()))
)

# %%
valores["res20_super"] .value_counts()
# Out:
# 10    719
# 9     481
# 0     409
# 19    334
# 6     157
# 13    146
# 1      83
# 7      75
# 17     75
# 16     63
# 3      58
# 12     57
# 4      56
# 18     52
# 14     49
# 2      44
# 11     39
# 8      39
# 15     38
# 5      26
# Name: res20_super, dtype: int64

# %% [markdown]
# otro

# %%
result20_super2 = pd.read_csv(ruta + "resvaloressuperkmeans2.csv")
valores["res20_super2"] = result20_super2

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="res20_super",
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['res20_super2'].unique()))
)

# %%
valores["res20_super2"].value_counts()
# Out:
# 8     431
# 11    426
# 3     343
# 17    333
# 15    243
# 9     165
# 16    159
# 2     153
# 14    146
# 12     91
# 5      87
# 1      64
# 10     58
# 0      51
# 13     47
# 7      46
# 6      43
# 4      42
# 19     38
# 18     34
# Name: res20_super2, dtype: int64

# %% [markdown]
# otro ejemplos

# %%
result20_super3 = pd.read_csv(ruta + "resvaloressuperkmeans3.csv")
valores["res20_super3"] = result20_super3
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="res20_super3",
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['res20_super3'].unique()))
)

# %%
valores["res20_super3"].value_counts()
# Out:
# 16    719
# 17    481
# 0     423
# 4     312
# 11    165
# 15    149
# 9      89
# 7      81
# 12     68
# 19     59
# 13     57
# 8      54
# 14     52
# 6      50
# 18     45
# 2      44
# 5      43
# 10     40
# 1      36
# 3      33
# Name: res20_super3, dtype: int64

# %% [markdown]
# # validando el silhouette

# %%
ressil = "valRessilh.csv"
ressildata = pd.read_csv(ruta + ressil)

# %%
valores["ressil"] = ressildata["res"]

# %%
result20_super3 = pd.read_csv(ruta + "resvaloressuperkmeans3.csv")
valores["res20_super3"] = result20_super3
#palette = sns.color_palette("RdBu", n_colors=20)
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="ressil",
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['ressil'].unique())),
    #style="time",
)

# %%
valores["ressil"].value_counts()
# Out:
# 1     719
# 4     481
# 12    333
# 0     243
# 7     165
# 8     159
# 13    152
# 17    150
# 6     149
# 9      97
# 2      53
# 15     52
# 18     50
# 10     46
# 5      44
# 19     40
# 3      39
# 14     28
# Name: ressil, dtype: int64

# %% [markdown]
# ## mil ejecuciones de prueba

# %%
ressil2 = "valRessilh1000.csv"
ressildata100 = pd.read_csv(ruta + ressil2)

# %%
valores["ressil1000"] = ressildata100["res"]

# %%
#palette = sns.color_palette("RdBu", n_colors=20)
plt.figure(figsize=(10,10))
sns.scatterplot(
    x="p1", y="p2",
    hue="ressil1000",
    data=valores,
    legend="full",
    palette =sns.color_palette("bright", len(valores['ressil1000'].unique())),
    #style="time",
)

# %%
valores["ressil1000"].value_counts()
# Out:
# 18    719
# 8     481
# 4     333
# 16    243
# 2     165
# 12    159
# 9     153
# 13    150
# 3     149
# 5     143
# 10     73
# 6      65
# 0      58
# 7      42
# 1      35
# 17     32
# Name: ressil1000, dtype: int64
